# %%
import matplotlib.pyplot as plt # plt 用于显示图片
import matplotlib.image as mpimg # mpimg 用于读取图片
import numpy as np

# %%
plt.rcParams['figure.figsize']=(24.8, 14.4)
img_s1 = mpimg.imread('D:/code/daily_record/someresults/result_5s/v_00HRwkvvjtQ_c011_000525/58.png')
img_s2 = mpimg.imread('D:/code/daily_record/someresults/result_5s/v_4r8QL_wglzQ_c001_000029/36.png')
img_s3 = mpimg.imread('D:/code/daily_record/someresults/result_5s/v_5ekaksddqrc_c004_000750/55.png')
img_s4 = mpimg.imread('D:/code/daily_record/someresults/result_5s/v_BgwzTUxJaeU_c012_000371/75.png')
img_e1 = mpimg.imread('D:/code/daily_record/someresults/result_5e/v_00HRwkvvjtQ_c011_000525/46.png')
img_e2 = mpimg.imread('D:/code/daily_record/someresults/result_5e/v_4r8QL_wglzQ_c001_000029/32.png')
img_e3 = mpimg.imread('D:/code/daily_record/someresults/result_5e/v_5ekaksddqrc_c004_000750/45.png')
img_e4 = mpimg.imread('D:/code/daily_record/someresults/result_5e/v_BgwzTUxJaeU_c012_000371/106.png')

# 此时 lena 就已经是一个 np.array 了，可以对它进行任意处理
plt.subplot(4,2,1)
plt.imshow(img_s1) # 显示图片
plt.axis('off')
plt.subplot(4,2,2)
plt.imshow(img_e1) # 显示图片
plt.axis('off')
plt.subplot(4,2,3)
plt.imshow(img_s2) # 显示图片
plt.axis('off')
plt.subplot(4,2,4)
plt.imshow(img_e2)
plt.axis('off')
plt.subplot(4,2,5)
plt.imshow(img_s3)
plt.axis('off')
plt.subplot(4,2,6)
plt.imshow(img_e3)
plt.axis('off')
plt.subplot(4,2,7)
plt.imshow(img_s4)
plt.axis('off')
plt.subplot(4,2,8)
plt.imshow(img_e4)
plt.axis('off')
 # 不显示坐标轴
plt.tight_layout() 
plt.savefig('D:/code/daily_record/heatmap.jpg')
plt.show()
